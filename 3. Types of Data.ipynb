# %% [markdown]
# # Major Type of Data
#
#     • Numerical
#     • Categorical
#     • Ordinal

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
