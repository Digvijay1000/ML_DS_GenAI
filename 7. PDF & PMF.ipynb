# %% [markdown]
# # Probability Density Function
#
# Possible distribution is 0.1, 0.81, 0.11 etc like so we dont findout exact range i.e continous data
#
# PDF gives us **exact range of given continous values**, i.e probabiity of a data point falling within some given range of a given values,finding probability that range is occuring in between +-16, +-26 or +-3d

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Probability Mass Function
#
# PMF is discrete probability of given discrete values occuring in data

# %% [markdown]
# ![image.png](attachment:image.png)
